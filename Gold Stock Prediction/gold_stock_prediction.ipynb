# %% [markdown]
# Importing Libraries and DataSet

# %%
import warnings
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from plotly import express as pex
import seaborn as sns
# %matplotlib inline

# %%
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
main_df=pd.read_csv('gold_stock.csv')
df=main_df.copy()
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
# ...

# %% [markdown]
# Showing every Aspect Of Dataset.

# %%
'''To check any duplicated values'''
df.duplicated()
df.duplicated().sum()
# Out:
# 0

# %%
len(df)
# Out:
# 1718

# %%
df.value_counts()
# Out:
# Date        Open        High        Low         Close       Adj Close   Volume    SP_open     SP_high     SP_low      SP_close    SP_Ajclose  SP_volume  DJ_open      DJ_high      DJ_low       DJ_close     DJ_Ajclose   DJ_volume  EG_open    EG_high    EG_low     EG_close   EG_Ajclose  EG_volume  EU_Price  EU_open  EU_high  EU_low  EU_Trend  OF_Price  OF_Open  OF_High  OF_Low  OF_Volume  OF_Trend  OS_Price  OS_Open  OS_High  OS_Low  OS_Trend  SF_Price  SF_Open  SF_High  SF_Low  SF_Volume  SF_Trend  USB_Price  USB_Open  USB_High  USB_Low  USB_Trend  PLT_Price  PLT_Open  PLT_High  PLT_Low  PLT_Trend  PLD_Price  PLD_Open  PLD_High  PLD_Low  PLD_Trend  RHO_PRICE  USDI_Price  USDI_Open  USDI_High  USDI_Low  USDI_Volume  USDI_Trend  GDX_Open   GDX_High   GDX_Low    GDX_Close  GDX_Adj Close  GDX_Volume  USO_Open   USO_High   USO_Low    USO_Close  USO_Adj Close  USO_Volume
# ...

# %%
df.drop('GDX_Close' , axis='columns')
df.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1  2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2  2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3  2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4  2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
#
#      Volume     SP_open     SP_high      SP_low  ...    GDX_Low  GDX_Close  \
# 0  21521900  123.029999  123.199997  121.989998  ...  51.570000  51.680000
# 1  18124300  122.230003  122.949997  121.300003  ...  52.040001  52.680000
# 2  12547200  122.059998  122.320000  120.029999  ...  51.029999  51.169998
# 3   9136300  122.180000  124.139999  120.370003  ...  52.369999  52.990002
# 4  11996100  123.930000  124.360001  122.750000  ...  52.419998  52.959999
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1718 non-null   object
#  1   Open           1718 non-null   float64
#  2   High           1718 non-null   float64
#  3   Low            1718 non-null   float64
#  4   Close          1718 non-null   float64
#  5   Adj Close      1718 non-null   float64
#  6   Volume         1718 non-null   int64
#  7   SP_open        1718 non-null   float64
#  8   SP_high        1718 non-null   float64
#  9   SP_low         1718 non-null   float64
#  10  SP_close       1718 non-null   float64
#  11  SP_Ajclose     1718 non-null   float64
#  12  SP_volume      1718 non-null   int64
#  13  DJ_open        1718 non-null   float64
#  14  DJ_high        1718 non-null   float64
#  15  DJ_low         1718 non-null   float64
#  16  DJ_close       1718 non-null   float64
# ...

# %%
#to measure the the dataset statistically
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1718.000000  1718.000000  1718.000000  1718.000000  1718.000000
# mean    127.323434   127.854237   126.777695   127.319482   127.319482
# std      17.526993    17.631189    17.396513    17.536269    17.536269
# min     100.919998   100.989998   100.230003   100.500000   100.500000
# 25%     116.220001   116.540001   115.739998   116.052502   116.052502
# 50%     121.915001   122.325001   121.369999   121.795002   121.795002
# 75%     128.427494   129.087498   127.840001   128.470001   128.470001
# max     173.199997   174.070007   172.919998   173.610001   173.610001
#
#              Volume      SP_open      SP_high       SP_low     SP_close  ...  \
# count  1.718000e+03  1718.000000  1718.000000  1718.000000  1718.000000  ...
# mean   8.446327e+06   204.490023   205.372637   203.487014   204.491222  ...
# std    4.920731e+06    43.831928    43.974644    43.618940    43.776999  ...
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Open             0
# High             0
# Low              0
# Close            0
#                 ..
# USO_High         0
# USO_Low          0
# USO_Close        0
# USO_Adj Close    0
# USO_Volume       0
# Length: 81, dtype: int64

# %%
# Showing All the Open Column in Stock with hist with different parameters.
df['Open'].plot(kind='hist')
df['Open'].plot(bins=50 , kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# This is Being Shown like this Because of the extremely Large DataSet.
df.hist(column='Open', by= 'USO_Volume')
# Out:
# array([[<AxesSubplot:title={'center':'1035100'}>,
#         <AxesSubplot:title={'center':'1155500'}>,
#         <AxesSubplot:title={'center':'1160100'}>, ...,
#         <AxesSubplot:title={'center':'1997900'}>,
#         <AxesSubplot:title={'center':'2000500'}>,
#         <AxesSubplot:title={'center':'2015600'}>],
#        [<AxesSubplot:title={'center':'2029100'}>,
#         <AxesSubplot:title={'center':'2030200'}>,
#         <AxesSubplot:title={'center':'2059500'}>, ...,
#         <AxesSubplot:title={'center':'2533500'}>,
#         <AxesSubplot:title={'center':'2539800'}>,
#         <AxesSubplot:title={'center':'2540500'}>],
#        [<AxesSubplot:title={'center':'2545800'}>,
#         <AxesSubplot:title={'center':'2552500'}>,
#         <AxesSubplot:title={'center':'2554200'}>, ...,
#         <AxesSubplot:title={'center':'3030200'}>,
#         <AxesSubplot:title={'center':'3034600'}>,
#         <AxesSubplot:title={'center':'3063800'}>],
#        ...,
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
'''To check co-relations between columns and rows'''
df.corr()
# Out:
#                    Open      High       Low     Close  Adj Close    Volume  \
# Open           1.000000  0.999515  0.999442  0.998976   0.998976  0.251921
# High           0.999515  1.000000  0.999262  0.999535   0.999535  0.261064
# Low            0.999442  0.999262  1.000000  0.999532   0.999532  0.237031
# Close          0.998976  0.999535  0.999532  1.000000   1.000000  0.246778
# Adj Close      0.998976  0.999535  0.999532  1.000000   1.000000  0.246778
# ...                 ...       ...       ...       ...        ...       ...
# USO_High       0.634864  0.637208  0.633623  0.635311   0.635311  0.083064
# USO_Low        0.634277  0.636538  0.633140  0.634732   0.634732  0.080475
# USO_Close      0.635138  0.637483  0.633994  0.635675   0.635675  0.081642
# USO_Adj Close  0.635138  0.637483  0.633994  0.635675   0.635675  0.081642
# USO_Volume    -0.455920 -0.454913 -0.457628 -0.456193  -0.456193  0.069580
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Creating an Extra 'Time' Parameter in The DataFrame To help in The predication

# %%
df['Time']= np.arange(len(df.index))
df
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1718.000000  1718.000000  1718.000000  1718.000000  1718.000000
# mean    127.323434   127.854237   126.777695   127.319482   127.319482
# std      17.526993    17.631189    17.396513    17.536269    17.536269
# min     100.919998   100.989998   100.230003   100.500000   100.500000
# 25%     116.220001   116.540001   115.739998   116.052502   116.052502
# 50%     121.915001   122.325001   121.369999   121.795002   121.795002
# 75%     128.427494   129.087498   127.840001   128.470001   128.470001
# max     173.199997   174.070007   172.919998   173.610001   173.610001
#
#              Volume      SP_open      SP_high       SP_low     SP_close  ...  \
# count  1.718000e+03  1718.000000  1718.000000  1718.000000  1718.000000  ...
# mean   8.446327e+06   204.490023   205.372637   203.487014   204.491222  ...
# std    4.920731e+06    43.831928    43.974644    43.618940    43.776999  ...
# ...

# %%
df.hist(column='Open', by= 'Time' )
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>, ...,
#         <AxesSubplot:title={'center':'38'}>,
#         <AxesSubplot:title={'center':'39'}>,
#         <AxesSubplot:title={'center':'40'}>],
#        [<AxesSubplot:title={'center':'41'}>,
#         <AxesSubplot:title={'center':'42'}>,
#         <AxesSubplot:title={'center':'43'}>, ...,
#         <AxesSubplot:title={'center':'79'}>,
#         <AxesSubplot:title={'center':'80'}>,
#         <AxesSubplot:title={'center':'81'}>],
#        [<AxesSubplot:title={'center':'82'}>,
#         <AxesSubplot:title={'center':'83'}>,
#         <AxesSubplot:title={'center':'84'}>, ...,
#         <AxesSubplot:title={'center':'120'}>,
#         <AxesSubplot:title={'center':'121'}>,
#         <AxesSubplot:title={'center':'122'}>],
#        ...,
#        [<AxesSubplot:title={'center':'1599'}>,
#         <AxesSubplot:title={'center':'1600'}>,
# ...

# %% [markdown]
# Splitting The Paramters.

# %%
X= df.loc[:,['Time']]
Y= df.loc[:, 'Open']

# %% [markdown]
# Showing All the Graphs To Better understand the Data.

# %%
plt.figure()

# %%
plt.figure( )
sns.barplot(data = df, x= 'Time' , y= 'Open')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Open'>

# %%
pex.hist(df, x = 'Time', y= 'Open',color = 'High', Title= 'Graphical Representation of Gold Stock ' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\vs code\gold_stock_prediction.ipynb Cell 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code/gold_stock_prediction.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> df.hist(df, x = 'Time', y= 'Open',color = 'High', Title= 'Graphical Representation of Gold Stock ' )
#
# File c:\Users\Lucifer\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:226, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     135 """
#     136 Make a histogram of the DataFrame's columns.
#     137
#    (...)
#     223     >>> hist = df.hist(bins=3)
#     224 """
#     225 plot_backend = _get_plot_backend(backend)
# --> 226 return plot_backend.hist_frame(
#     227     data,
#     228     column=column,
# ...

# %%
sns.pairplot(df)

# %%
pex(df, x='Time', y='Open', marginal_x='histogram', marginal_y= 'histogram', )

# %%
sns.relplot(x= 'Time', y='USO_Volume', hue='Open', data =df)

# %% [markdown]
# Making a Model

# %%
lreg= LinearRegression().fit(X,Y)
print('Score=' , score(X, Y))

# %%
# Predicting X
y_pred = lreg.predict(X)

# Plotting feature and lr
df.Open.plot.line()
plt.plot(y_pred)
plt.show()
